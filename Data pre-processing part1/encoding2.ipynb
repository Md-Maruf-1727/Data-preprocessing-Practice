# %%
import pandas as pd
import seaborn as sns
import numpy as np 
import requests
from io import StringIO
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
tipsDataSet = sns.load_dataset('tips')

# %%
tipsDataSet.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tipsDataSet.shape
# Out:
# (244, 7)

# %%
tipsDataSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tipsDataSet.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tipsDataSet['total_bill'].value_counts()
# Out:
# total_bill
# 13.42    3
# 21.01    2
# 20.69    2
# 10.33    2
# 10.34    2
#         ..
# 29.03    1
# 27.18    1
# 22.67    1
# 17.82    1
# 18.78    1
# Name: count, Length: 229, dtype: int64

# %%
tipsDataSet['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
tipsDataSet['tip'].value_counts()
# Out:
# tip
# 2.00    33
# 3.00    23
# 4.00    12
# 2.50    10
# 5.00    10
#         ..
# 1.47     1
# 1.17     1
# 4.67     1
# 5.92     1
# 1.75     1
# Name: count, Length: 123, dtype: int64

# %%
tipsDataSet['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
tipsDataSet['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
tipsDataSet['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
tipsDataSet['time'].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
tipsDataSet['size'].value_counts()
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
tipsDataSet.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
for col in tipsDataSet.loc[:,['sex','smoker','day','time','size']]:
    val = tipsDataSet[col].value_counts()
    print(val)
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
label_en = LabelEncoder()

# %%
tipsDataSet.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tipsDataSet['sex'] = label_en.fit_transform(tipsDataSet['sex'])

# %%
tipsDataSet.head()
# Out:
#    total_bill   tip  sex smoker  day    time  size
# 0       16.99  1.01    0     No  Sun  Dinner     2
# 1       10.34  1.66    1     No  Sun  Dinner     3
# 2       21.01  3.50    1     No  Sun  Dinner     3
# 3       23.68  3.31    1     No  Sun  Dinner     2
# 4       24.59  3.61    0     No  Sun  Dinner     4

# %%
tipsDataSet['smoker'] = label_en.fit_transform(tipsDataSet['smoker'])

# %%
tipsDataSet.head()
# Out:
#    total_bill   tip  sex  smoker  day    time  size
# 0       16.99  1.01    0       0  Sun  Dinner     2
# 1       10.34  1.66    1       0  Sun  Dinner     3
# 2       21.01  3.50    1       0  Sun  Dinner     3
# 3       23.68  3.31    1       0  Sun  Dinner     2
# 4       24.59  3.61    0       0  Sun  Dinner     4

# %%
tipsDataSet['smoker'].value_counts()
# Out:
# smoker
# 0    151
# 1     93
# Name: count, dtype: int64

# %%
tipsDataSet['day'] = label_en.fit_transform(tipsDataSet['day'])
tipsDataSet.head()
# Out:
#    total_bill   tip  sex  smoker  day    time  size
# 0       16.99  1.01    0       0    2  Dinner     2
# 1       10.34  1.66    1       0    2  Dinner     3
# 2       21.01  3.50    1       0    2  Dinner     3
# 3       23.68  3.31    1       0    2  Dinner     2
# 4       24.59  3.61    0       0    2  Dinner     4

# %%
tipsDataSet['day'].value_counts()
# Out:
# day
# 1    87
# 2    76
# 3    62
# 0    19
# Name: count, dtype: int64

# %%
tipsDataSet['time'] = label_en.fit_transform(tipsDataSet['time'])
tipsDataSet.head()
# Out:
#    total_bill   tip  sex  smoker  day  time  size
# 0       16.99  1.01    0       0    2     0     2
# 1       10.34  1.66    1       0    2     0     3
# 2       21.01  3.50    1       0    2     0     3
# 3       23.68  3.31    1       0    2     0     2
# 4       24.59  3.61    0       0    2     0     4

# %%
tipsDataSet['time'].value_counts()
# Out:
# time
# 0    176
# 1     68
# Name: count, dtype: int64

# %%
url1 = "https://raw.githubusercontent.com/pooja2512/Adult-Census-Income/refs/heads/master/adult.csv"
data1 = requests.get(url1)
str_io1 = StringIO(data1.text)
adult_in_d = pd.read_csv(str_io1)

# %%
adult_in_d.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %%
adult_in_d.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'income'],
#       dtype='object')

# %%
adult_in_d['workclass'].value_counts()
# Out:
# workclass
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64

# %%
adult_in_d.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
adult_in_d['education'].value_counts()
# Out:
# education
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: count, dtype: int64

# %%
adult_in_d['marital.status'].value_counts()
# Out:
# marital.status
# Married-civ-spouse       14976
# Never-married            10683
# Divorced                  4443
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: count, dtype: int64

# %%
adult_in_d.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'income'],
#       dtype='object')

# %%
adult_in_d['native.country'].value_counts()
# Out:
# native.country
# United-States                 29170
# Mexico                          643
# ?                               583
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# ...

# %%
adult_in_d['occupation'].value_counts()
# Out:
# occupation
# Prof-specialty       4140
# Craft-repair         4099
# Exec-managerial      4066
# Adm-clerical         3770
# Sales                3650
# Other-service        3295
# Machine-op-inspct    2002
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1370
# Farming-fishing       994
# Tech-support          928
# Protective-serv       649
# Priv-house-serv       149
# Armed-Forces            9
# Name: count, dtype: int64

# %%
adult_in_d['relationship'].value_counts()
# Out:
# relationship
# Husband           13193
# Not-in-family      8305
# Own-child          5068
# Unmarried          3446
# Wife               1568
# Other-relative      981
# Name: count, dtype: int64

# %%
adult_in_d.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'income'],
#       dtype='object')

# %%
adult_in_d['native.country'].value_counts()
# Out:
# native.country
# United-States                 29170
# Mexico                          643
# ?                               583
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# ...

# %%
adult_in_d['race'].value_counts()
# Out:
# race
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: count, dtype: int64

# %%
adult_in_d['sex'].value_counts()
# Out:
# sex
# Male      21790
# Female    10771
# Name: count, dtype: int64

# %%
adult_in_d['income'].value_counts()
# Out:
# income
# <=50K    24720
# >50K      7841
# Name: count, dtype: int64

# %%
adult_in_d.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'income'],
#       dtype='object')

# %%
adult_in_d['workclass'] = label_en.fit_transform(adult_in_d['workclass'])
adult_in_d.head()
# Out:
#    age  workclass  fnlwgt     education  education.num marital.status  \
# 0   90          0   77053       HS-grad              9        Widowed
# 1   82          4  132870       HS-grad              9        Widowed
# 2   66          0  186061  Some-college             10        Widowed
# 3   54          4  140359       7th-8th              4       Divorced
# 4   41          4  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %%
adult_in_d['workclass'].value_counts()
# Out:
# workclass
# 4    22696
# 6     2541
# 2     2093
# 0     1836
# 7     1298
# 5     1116
# 1      960
# 8       14
# 3        7
# Name: count, dtype: int64

# %%
edu_en = label_en.fit(adult_in_d['education'])
edu_en
# Out:
# LabelEncoder()

# %%
adult_in_d['education'] = edu_en.transform(adult_in_d['education'])

# %%
adult_in_d.head(2)
# Out:
#    age  workclass  fnlwgt  education  education.num marital.status  \
# 0   90          0   77053         11              9        Widowed
# 1   82          4  132870         11              9        Widowed
#
#         occupation   relationship   race     sex  capital.gain  capital.loss  \
# 0                ?  Not-in-family  White  Female             0          4356
# 1  Exec-managerial  Not-in-family  White  Female             0          4356
#
#    hours.per.week native.country income
# 0              40  United-States  <=50K
# 1              18  United-States  <=50K

# %%
adult_in_d['education'].value_counts()
# Out:
# education
# 11    10501
# 15     7291
# 9      5355
# 12     1723
# 8      1382
# 1      1175
# 7      1067
# 0       933
# 5       646
# 14      576
# 6       514
# 2       433
# 10      413
# 4       333
# 3       168
# 13       51
# Name: count, dtype: int64

# %%
merit_en = label_en.fit(adult_in_d['marital.status'])
merit_en
# Out:
# LabelEncoder()

# %%
adult_in_d['marital.status'] = label_en.transform(adult_in_d['marital.status'])

# %%
adult_in_d['marital.status'].value_counts()
# Out:
# marital.status
# 2    14976
# 4    10683
# 0     4443
# 5     1025
# 6      993
# 3      418
# 1       23
# Name: count, dtype: int64

# %%
adult_in_d.head(2)
# Out:
#    age  workclass  fnlwgt  education  education.num  marital.status  \
# 0   90          0   77053         11              9               6
# 1   82          4  132870         11              9               6
#
#         occupation   relationship   race     sex  capital.gain  capital.loss  \
# 0                ?  Not-in-family  White  Female             0          4356
# 1  Exec-managerial  Not-in-family  White  Female             0          4356
#
#    hours.per.week native.country income
# 0              40  United-States  <=50K
# 1              18  United-States  <=50K

# %%
occu_en = label_en.fit(adult_in_d['occupation'])
occu_en
# Out:
# LabelEncoder()

# %%
adult_in_d['occupation'] = occu_en.transform(adult_in_d['occupation'])

# %%
adult_in_d['occupation'].value_counts()
# Out:
# occupation
# 10    4140
# 3     4099
# 4     4066
# 1     3770
# 12    3650
# 8     3295
# 7     2002
# 0     1843
# 14    1597
# 6     1370
# 5      994
# 13     928
# 11     649
# 9      149
# 2        9
# Name: count, dtype: int64

# %%
adult_in_d.head(3)
# Out:
#    age  workclass  fnlwgt  education  education.num  marital.status  \
# 0   90          0   77053         11              9               6
# 1   82          4  132870         11              9               6
# 2   66          0  186061         15             10               6
#
#    occupation   relationship   race     sex  capital.gain  capital.loss  \
# 0           0  Not-in-family  White  Female             0          4356
# 1           4  Not-in-family  White  Female             0          4356
# 2           0      Unmarried  Black  Female             0          4356
#
#    hours.per.week native.country income
# 0              40  United-States  <=50K
# 1              18  United-States  <=50K
# 2              40  United-States  <=50K

# %%
adult_in_d['relationship'] = label_en.fit_transform(adult_in_d['relationship'])
adult_in_d['relationship'].value_counts()
# Out:
# relationship
# 0    13193
# 1     8305
# 3     5068
# 4     3446
# 5     1568
# 2      981
# Name: count, dtype: int64

# %%
adult_in_d['race'] = label_en.fit_transform(adult_in_d['race'])
adult_in_d['race'].value_counts()
# Out:
# race
# 4    27816
# 2     3124
# 1     1039
# 0      311
# 3      271
# Name: count, dtype: int64

# %%
adult_in_d['sex'] = label_en.fit_transform(adult_in_d['sex'])
adult_in_d['sex'].value_counts()
# Out:
# sex
# 1    21790
# 0    10771
# Name: count, dtype: int64

# %%
adult_in_d['income'] = label_en.fit_transform(adult_in_d['income'])
adult_in_d['income'].value_counts()
# Out:
# income
# 0    24720
# 1     7841
# Name: count, dtype: int64

# %%
adult_in_d.head()
# Out:
#    age  workclass  fnlwgt  education  education.num  marital.status  \
# 0   90          0   77053         11              9               6
# 1   82          4  132870         11              9               6
# 2   66          0  186061         15             10               6
# 3   54          4  140359          5              4               0
# 4   41          4  264663         15             10               5
#
#    occupation  relationship  race  sex  capital.gain  capital.loss  \
# 0           0             1     4    0             0          4356
# 1           4             1     4    0             0          4356
# 2           0             4     2    0             0          4356
# 3           7             4     4    0             0          3900
# 4          10             3     4    0             0          3900
#
#    hours.per.week native.country  income
# 0              40  United-States       0
# 1              18  United-States       0
# ...

# %%
adult_in_d['native.country']= label_en.fit_transform(adult_in_d['native.country'])
adult_in_d['native.country'].value_counts()
# Out:
# native.country
# 39    29170
# 26      643
# 0       583
# 30      198
# 11      137
# 2       121
# 33      114
# 8       106
# 19      100
# 5        95
# 9        90
# 23       81
# 35       80
# 3        75
# 22       73
# 6        70
# 40       67
# 13       64
# 24       62
# 31       60
# 4        59
# 36       51
# 14       44
# 20       43
# 32       37
# 27       34
# 29       31
# 12       29
# 10       29
# 7        28
# 21       24
# 17       20
# 38       19
# 1        19
# 37       18
# 25       18
# 41       16
# 28       14
# 18       13
# 16       13
# 34       12
# 15        1
# Name: count, dtype: int64

# %%
adult_in_d.head()
# Out:
#    age  workclass  fnlwgt  education  education.num  marital.status  \
# 0   90          0   77053         11              9               6
# 1   82          4  132870         11              9               6
# 2   66          0  186061         15             10               6
# 3   54          4  140359          5              4               0
# 4   41          4  264663         15             10               5
#
#    occupation  relationship  race  sex  capital.gain  capital.loss  \
# 0           0             1     4    0             0          4356
# 1           4             1     4    0             0          4356
# 2           0             4     2    0             0          4356
# 3           7             4     4    0             0          3900
# 4          10             3     4    0             0          3900
#
#    hours.per.week  native.country  income
# 0              40              39       0
# 1              18              39       0
# ...

# %%
penguin_data_set = sns.load_dataset("penguins")

# %%
penguin_data_set
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguin_data_set.shape
# Out:
# (344, 7)

# %%
penguin_data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
penguin_data_set.isna().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
penguin_data_set['bill_length_mm'] = penguin_data_set['bill_length_mm'].fillna(penguin_data_set['bill_length_mm'].mean())

# %%
penguin_data_set['bill_depth_mm'] = penguin_data_set['bill_depth_mm'].fillna(penguin_data_set['bill_depth_mm'].mean())

# %%
penguin_data_set['flipper_length_mm'] = penguin_data_set['flipper_length_mm'].fillna(penguin_data_set['flipper_length_mm'].mean())

# %%
penguin_data_set['body_mass_g'] = penguin_data_set['body_mass_g'].fillna(penguin_data_set['body_mass_g'].mean())

# %%
penguin_data_set['sex'] = penguin_data_set['sex'].ffill()

# %%
penguin_data_set.isna().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64
